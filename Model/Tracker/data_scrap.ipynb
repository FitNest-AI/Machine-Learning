# %%
import os
import pandas as pd
import numpy as np

# %%
from bs4 import BeautifulSoup
import requests

def get(food_name):

    site = requests.get("https://www.fatsecret.co.id/kalori-gizi/umum/" + food_name.replace(" ", "-"))
    bsoup = BeautifulSoup(site.text, features="html.parser")

    facts = bsoup.find_all('td', class_='fact')

    data = ['Calories', 'Fat', 'Carbs', 'Protein']
    values = []
    for fact in facts:
        value = fact.find('div', class_='factValue').text
        values.append(float(value.replace('g','').replace('kcal','').strip().replace(',','.')))
    
    return data, values

# %%
def get_food_group(group_name):
    site = requests.get("https://www.fatsecret.co.id/kalori-gizi/grup/" + group_name)
    bsoup = BeautifulSoup(site.text, features="html.parser")
    food_name = bsoup.find_all("div", class_="food_links")
    food_list = []
    for name in food_name:
        name = name.text.split(',')[0]
        food = get(name)
        print(name,food)
        print("=====================================")
        food_list.append((name,food))
    return food_list

# %%
food_list = ["biji-bijian","buah","daging","ikan-seafood","kacang-kacangan","keju%C2%A0-susu","makanan-cepat-saji"
             ,"makanan penutup","makanan ringan","nasi%C2%A0mie%C2%A0-%C2%A0pasta","roti-sereal",
             "salad","sayuran","sup",""]

food_data = []

for group in food_list:
    food_data.append(get_food_group(group))
# Out:
# Biji Bunga Matahari (yang) Dikuliti Sangrai Kering (['Calories', 'Fat', 'Carbs', 'Protein'], [582.0, 49.8, 24.07, 19.33])
# =====================================
# Biji Wijen Kering Utuh (['Calories', 'Fat', 'Carbs', 'Protein'], [52.0, 4.47, 2.11, 1.6])
# =====================================
# Kacang Almond (['Calories', 'Fat', 'Carbs', 'Protein'], [578.0, 50.64, 19.74, 21.26])
# =====================================
# Kacang Campuran (['Calories', 'Fat', 'Carbs', 'Protein'], [876.0, 79.95, 30.64, 23.44])
# =====================================
# Kacang Kedelai (['Calories', 'Fat', 'Carbs', 'Protein'], [471.0, 25.4, 33.55, 35.22])
# =====================================
# Kacang Mete (['Calories', 'Fat', 'Carbs', 'Protein'], [581.0, 47.77, 30.16, 16.84])
# =====================================
# Kacang Tanah (['Calories', 'Fat', 'Carbs', 'Protein'], [567.0, 49.24, 16.13, 25.8])
# =====================================
# Kacang Campuran (['Calories', 'Fat', 'Carbs', 'Protein'], [876.0, 79.95, 30.64, 23.44])
# =====================================
# Kacang Kemiri (['Calories', 'Fat', 'Carbs', 'Protein'], [691.0, 71.97, 13.86, 9.17])
# =====================================
# Alpukat (['Calories', 'Fat', 'Carbs', 'Protein'], [322.0, 29.47, 17.15, 4.02])
# =====================================
# Buah Anggur (['Calories', 'Fat', 'Carbs', 'Protein'], [3.0, 0.01, 0.9, 0.04])
# =====================================
# Apel (['Calories', 'Fat', 'Carbs', 'Protein'], [72.0, 0.23, 19.06, 0.36])
# =====================================
# Blewah Melon (['Calories', 'Fat', 'Carbs', 'Protein'], [19.0, 0.1, 4.49, 0.46])
# =====================================
# Blueberi (['Calories', 'Fat', 'Carbs', 'Protein'], [57.0, 0.33, 14.49, 0.74])
# =====================================
# Beri (['Calories', 'Fat', 'Carbs', 'Protein'], [48.0, 0.43, 11.49, 0.98])
# =====================================
# Campuran Buah Kering (['Calories', 'Fat', 'Carbs', 'Protein'], [332.0, 0.6, 88.14, 2.98])
# =====================================
# Buah Pir (['Calories', 'Fat', 'Carbs', 'Protein'], [96.0, 0.2, 25.66, 0.63])
# =====================================
# Ceri Manis (['Calories', 'Fat', 'Carbs', 'Protein'], [74.0, 0.23, 18.73, 1.24])
# =====================================
# Jeruk (['Calories', 'Fat', 'Carbs', 'Protein'], [62.0, 0.16, 15.39, 1.23])
# =====================================
# Jeruk Bali (['Calories', 'Fat', 'Carbs', 'Protein'], [32.0, 0.1, 8.08, 0.63])
# =====================================
# Jeruk Keprok (Jeruk Mandarin) (['Calories', 'Fat', 'Carbs', 'Protein'], [37.0, 0.22, 9.34, 0.57])
# =====================================
# Kelapa (['Calories', 'Fat', 'Carbs', 'Protein'], [354.0, 33.49, 15.23, 3.33])
# =====================================
# Kismis (['Calories', 'Fat', 'Carbs', 'Protein'], [299.0, 0.46, 79.18, 3.07])
# =====================================
# Kurma (['Calories', 'Fat', 'Carbs', 'Protein'], [23.0, 0.03, 6.23, 0.2])
# =====================================
# Mangga (['Calories', 'Fat', 'Carbs', 'Protein'], [107.0, 0.45, 28.05, 0.84])
# =====================================
# Blewah Melon (['Calories', 'Fat', 'Carbs', 'Protein'], [19.0, 0.1, 4.49, 0.46])
# =====================================
# Nanas (['Calories', 'Fat', 'Carbs', 'Protein'], [48.0, 0.12, 12.63, 0.54])
# =====================================
# Pepaya (['Calories', 'Fat', 'Carbs', 'Protein'], [55.0, 0.2, 13.73, 0.85])
# =====================================
# Pisang (['Calories', 'Fat', 'Carbs', 'Protein'], [105.0, 0.39, 26.95, 1.29])
# =====================================
# Rasberi (['Calories', 'Fat', 'Carbs', 'Protein'], [64.0, 0.8, 14.69, 1.48])
# =====================================
# Salad Buah (['Calories', 'Fat', 'Carbs', 'Protein'], [54.0, 0.81, 12.5, 0.63])
# =====================================
# Semangka (['Calories', 'Fat', 'Carbs', 'Protein'], [30.0, 0.15, 7.55, 0.61])
# =====================================
# Stroberi (['Calories', 'Fat', 'Carbs', 'Protein'], [32.0, 0.3, 7.68, 0.67])
# =====================================
# Ayam (['Calories', 'Fat', 'Carbs', 'Protein'], [17.0, 0.94, 0.0, 1.89])
# =====================================
# Ayam Goreng tanpa Pelapis (Kulit Dimakan) (['Calories', 'Fat', 'Carbs', 'Protein'], [18.0, 1.07, 0.0, 2.0])
# =====================================
# Daging Ayam (Panggang) (['Calories', 'Fat', 'Carbs', 'Protein'], [111.0, 2.7, 0.0, 20.33])
# =====================================
# Daging Babi Panggang (['Calories', 'Fat', 'Carbs', 'Protein'], [247.0, 14.59, 0.0, 26.98])
# =====================================
# Bakso Daging Sapi (['Calories', 'Fat', 'Carbs', 'Protein'], [57.0, 3.69, 2.12, 3.47])
# =====================================
# Daging Bebek (['Calories', 'Fat', 'Carbs', 'Protein'], [132.0, 5.95, 0.0, 18.28])
# =====================================
# Dada Ayam (['Calories', 'Fat', 'Carbs', 'Protein'], [195.0, 7.72, 0.0, 29.55])
# =====================================
# Daging Dada Kalkun (['Calories', 'Fat', 'Carbs', 'Protein'], [104.0, 1.66, 4.21, 17.07])
# =====================================
# Daging Babi (['Calories', 'Fat', 'Carbs', 'Protein'], [363.0, 22.83, 0.0, 36.64])
# =====================================
# Potongan Daging Domba (['Calories', 'Fat', 'Carbs', 'Protein'], [226.0, 17.55, 0.0, 15.86])
# =====================================
# Daging Sapi (['Calories', 'Fat', 'Carbs', 'Protein'], [288.0, 19.54, 0.0, 26.33])
# =====================================
# Daging Sapi Giling (['Calories', 'Fat', 'Carbs', 'Protein'], [276.0, 18.58, 0.0, 25.35])
# =====================================
# Daging Sapi Panggang (['Calories', 'Fat', 'Carbs', 'Protein'], [56.0, 3.64, 0.0, 5.44])
# =====================================
# Daging Domba (['Calories', 'Fat', 'Carbs', 'Protein'], [292.0, 20.77, 0.0, 24.32])
# =====================================
# Iga Babi (['Calories', 'Fat', 'Carbs', 'Protein'], [395.0, 30.17, 0.0, 28.94])
# =====================================
# Kalkun (['Calories', 'Fat', 'Carbs', 'Protein'], [26.0, 0.98, 0.0, 4.05])
# =====================================
# Paha Ayam (['Calories', 'Fat', 'Carbs', 'Protein'], [135.0, 8.45, 0.0, 13.67])
# =====================================
# Punggung Sapi (['Calories', 'Fat', 'Carbs', 'Protein'], [72.0, 5.49, 0.0, 5.22])
# =====================================
# Sayap Ayam (['Calories', 'Fat', 'Carbs', 'Protein'], [81.0, 5.4, 0.0, 7.46])
# =====================================
# Sosis Daging Sapi (['Calories', 'Fat', 'Carbs', 'Protein'], [42.0, 3.78, 0.52, 1.44])
# =====================================
# Cumi Goreng (['Calories', 'Fat', 'Carbs', 'Protein'], [12.0, 0.21, 0.96, 1.47])
# =====================================
# Cumi-cumi (['Calories', 'Fat', 'Carbs', 'Protein'], [92.0, 1.38, 3.08, 15.58])
# =====================================
# Gurita (['Calories', 'Fat', 'Carbs', 'Protein'], [82.0, 1.04, 2.2, 14.91])
# =====================================
# Udang (['Calories', 'Fat', 'Carbs', 'Protein'], [7.0, 0.12, 0.06, 1.38])
# =====================================
# Ikan (['Calories', 'Fat', 'Carbs', 'Protein'], [84.0, 0.92, 0.0, 17.76])
# =====================================
# Kakap (Ikan) (Spesies Campuran) (['Calories', 'Fat', 'Carbs', 'Protein'], [100.0, 1.34, 0.0, 20.51])
# =====================================
# Ikan Kembung (['Calories', 'Fat', 'Carbs', 'Protein'], [167.0, 9.36, 0.0, 19.32])
# =====================================
# Ikan Lele (['Calories', 'Fat', 'Carbs', 'Protein'], [204.0, 12.35, 7.26, 14.93])
# =====================================
# Ikan Salmon (['Calories', 'Fat', 'Carbs', 'Protein'], [146.0, 5.93, 0.0, 21.62])
# =====================================
# Ikan Sarden dalam Minyak (Kalengan) (['Calories', 'Fat', 'Carbs', 'Protein'], [25.0, 1.37, 0.0, 2.95])
# =====================================
# Ikan Teri (Kering Padat dalam Minyak (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Tuna dalam Air (Kalengan) (['Calories', 'Fat', 'Carbs', 'Protein'], [116.0, 0.82, 0.0, 25.51])
# =====================================
# Kepiting (['Calories', 'Fat', 'Carbs', 'Protein'], [119.0, 2.08, 0.0, 23.64])
# =====================================
# Kerang (['Calories', 'Fat', 'Carbs', 'Protein'], [35.0, 1.75, 1.68, 2.9])
# =====================================
# Lobster (['Calories', 'Fat', 'Carbs', 'Protein'], [114.0, 0.68, 1.5, 23.99])
# =====================================
# Dimasak Hidup-hidup (['Calories', 'Fat', 'Carbs', 'Protein'], [133.0, 4.24, 0.41, 22.0])
# =====================================
# Tiram (['Calories', 'Fat', 'Carbs', 'Protein'], [33.0, 1.18, 1.88, 3.38])
# =====================================
# Udang (['Calories', 'Fat', 'Carbs', 'Protein'], [7.0, 0.12, 0.06, 1.38])
# =====================================
# Udang Karang (Udang) (['Calories', 'Fat', 'Carbs', 'Protein'], [72.0, 0.97, 0.0, 14.85])
# =====================================
# Buncis (['Calories', 'Fat', 'Carbs', 'Protein'], [31.0, 0.12, 7.13, 1.82])
# =====================================
# Buncis (['Calories', 'Fat', 'Carbs', 'Protein'], [31.0, 0.12, 7.13, 1.82])
# =====================================
# Kacang Belang (Biji Matang (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Kacang Merah (Kalengan) (['Calories', 'Fat', 'Carbs', 'Protein'], [218.0, 0.87, 39.91, 13.44])
# =====================================
# Kacang Panggang (['Calories', 'Fat', 'Carbs', 'Protein'], [151.0, 5.15, 21.39, 5.54])
# =====================================
# Tahu Goreng (['Calories', 'Fat', 'Carbs', 'Protein'], [35.0, 2.62, 1.36, 2.23])
# =====================================
# Keju Cheddar (['Calories', 'Fat', 'Carbs', 'Protein'], [403.0, 33.14, 1.28, 24.9])
# =====================================
# Keju Parmesan (Diparut) (['Calories', 'Fat', 'Carbs', 'Protein'], [415.0, 27.34, 3.41, 37.86])
# =====================================
# Keju Krim (['Calories', 'Fat', 'Carbs', 'Protein'], [51.0, 5.06, 0.39, 1.09])
# =====================================
# Margarin (['Calories', 'Fat', 'Carbs', 'Protein'], [75.0, 8.46, 0.0, 0.09])
# =====================================
# Mentega (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Susu (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Susu (tanpa Lemak) (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Yogurt Polos (['Calories', 'Fat', 'Carbs', 'Protein'], [63.0, 1.55, 7.04, 5.25])
# =====================================
# Chicken Nugget (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Bubuk Kari (['Calories', 'Fat', 'Carbs', 'Protein'], [6.0, 0.28, 1.16, 0.25])
# =====================================
# Kentang Goreng (['Calories', 'Fat', 'Carbs', 'Protein'], [156.0, 8.01, 20.33, 1.98])
# =====================================
# Pizza Keju (['Calories', 'Fat', 'Carbs', 'Protein'], [237.0, 10.1, 26.08, 10.6])
# =====================================
# Pizza Keju (['Calories', 'Fat', 'Carbs', 'Protein'], [237.0, 10.1, 26.08, 10.6])
# =====================================
# Taco atau Tostada dengan Ayam (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Makaroni (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Makaroni atau Mie dengan Keju (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Mie (['Calories', 'Fat', 'Carbs', 'Protein'], [219.0, 3.3, 40.02, 7.22])
# =====================================
# Nasi Putih Instan (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Nasi Goreng (['Calories', 'Fat', 'Carbs', 'Protein'], [333.0, 12.34, 41.7, 12.47])
# =====================================
# Nasi Merah (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Nasi Putih (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================
# Spageti (['Calories', 'Fat', 'Carbs', 'Protein'], [])
# =====================================

# %%
print(food_data)
# Out:
# []
